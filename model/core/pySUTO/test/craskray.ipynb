# %%
from opt.Diagnostics import Diagnostics
import os
import numpy as np
import matplotlib.pyplot as plt
# change working directory for relative dependencies
os.chdir('/mnt/nfs_fineprint/tmp/PYSUT/pySUTO')

# %%
path = '/mnt/nfs_fineprint/tmp/PYSUT/pySUTO/data/proc/opt/craskras_cathode_test_run'

diag = Diagnostics.load(path)

# %%
type(diag)
print(os.getcwd())
# Out:
# /mnt/nfs_fineprint/tmp/PYSUT/pySUTO

# %%
diag.plot_convergence(name = 'cathod_convergence.png')

# %%
diag.plot_c_init_final(name = 'cathod_c_init_final.png', xlog=True, ylog=True)

# %%
diag.plot_a_init_final(name = 'cathod_a_init_final.png', xlog=True, ylog=True)

# %%
#diag.a_init
diag.a_final
# Out:
# array([0.001, 0.001, 0.001, ..., 0.001, 0.45 , 0.199], shape=(42394,))

# %%
diff = diag.a_final - diag.a_init
rel_diff = diff / diag.a_init
rel_diff = rel_diff[~np.isnan(rel_diff)]
np.mean(rel_diff)
# Out:
# /tmp/ipykernel_125482/3756392229.py:2: RuntimeWarning: invalid value encountered in divide
#   rel_diff = diff / diag.a_init
# np.float64(0.10458769142067262)

# %%
diag.c_init
# Out:
# array([1.60000000e+01, 1.66670000e+01, 1.11100000e+00, ...,
#        9.99999997e-07, 9.99999997e-07, 9.99999997e-07], shape=(3321,))

# %%
diag.c_final
# Out:
# array([1.00000000e-03, 8.20000000e-02, 6.03200000e+00, ...,
#        7.13875571e+03, 9.99999997e-07, 9.99999997e-07], shape=(3321,))

# %%
diag.plot_c_diff_histogram(name = 'cathod_c_diff_histogram.png')

# %%
diag.hist(name = 'cathod_hist.png', a_x_log=True)
